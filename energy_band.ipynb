# %% [markdown]
# ## Kronig-Penney Model

# %%
from numpy import pi
import EnergyBand as EB

# %%
EB.E?
# Out:
# Signature:       EB.E(*args, **kwargs)
# Type:            vectorize
# String form:     <numpy.vectorize object at 0x7effc87e3370>
# File:            ~/.local/lib/python3.8/site-packages/numpy/__init__.py
# Docstring:
# Get energy from k in Kronig-Penney model.
# ---
# Arguments:
#     k: wavenumber, a number or an numpy.array.
#     n: the n-th band, starting from 0.
#     a: distance between atoms.
#     U0b: the area of the potential wall.
#     **kwargs: something else to pass to scipy.optimize.fsolve.
# Returns:
#     The energies corresponding to k, in the unit of hbar^2/2m.
# Class docstring:
# vectorize(pyfunc, otypes=None, doc=None, excluded=None, cache=False,
#           signature=None)
#
# Generalized function class.
#
# Define a vectorized function which takes a nested sequence of objects or
# numpy arrays as inputs and returns a single numpy array or a tuple of numpy
# arrays. The vectorized function evaluates `pyfunc` over successive tuples
# ...

# %%
"E = {:.3f} hbar^2/2m for k=pi, a=1, U_0b=4".format(*EB.E(pi, 1))
# Out:
# 'E = 16.463 hbar^2/2m for k=pi, a=1, U_0b=4'

# %%
EB.getBands()
# Out:
# [array([9.8696044 , 9.84981249, 9.79143385, 9.69726144, 9.57137463,
#         9.41851404, 9.24352647, 9.05097747, 8.84494025, 8.62892083,
#         8.40586845, 8.17822975, 7.94801906, 7.71688959, 7.48619802,
#         7.25705979, 7.03039502, 6.80696586, 6.58740651, 6.37224735,
#         6.16193411, 5.95684327, 5.75729438, 5.56355994, 5.3758734 ,
#         5.19443557, 5.01941993, 4.85097687, 4.68923727, 4.53431533,
#         4.38631104, 4.24531213, 4.11139576, 3.98462991, 3.86507456,
#         3.75278266, 3.647801  , 3.55017088, 3.45992877, 3.37710673,
#         3.30173297, 3.23383209, 3.17342551, 3.12053164, 3.07516616,
#         3.03734221, 3.00707049, 2.98435944, 2.96921531, 2.96164222,
#         2.96164222, 2.96921531, 2.98435944, 3.00707049, 3.03734221,
#         3.07516616, 3.12053164, 3.17342551, 3.23383209, 3.30173297,
#         3.37710673, 3.45992877, 3.55017088, 3.647801  , 3.75278266,
#         3.86507456, 3.98462991, 4.11139576, 4.24531213, 4.38631104,
# ...

# %%
fig, ax = EB.plotBands(n=5)
fig.show()
